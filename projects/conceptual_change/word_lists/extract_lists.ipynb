# %%
import re

# %%
with open('list-of-contemporary-ethnic-groups.csv', 'r') as infile:
    #for line in infile.read().split('\n')
    words = [line.split('\t')[0] for line in infile.read().split('\n')[1:]]

# %%
p = re.compile('[*]')
print p, type(p)

print str(p)
# Out:
# <_sre.SRE_Pattern object at 0x7f907822d608> <type '_sre.SRE_Pattern'>
# ...

# %%
words
# Out:
# ['Acholi',
#  'Akan',
#  'Albanians',
#  'Afar',
#  'Afrikaners',
#  'Amhara',
#  'Arabs',
#  'Armenians',
#  'Assamese',
#  'Assyrians',
#  'Azerbaijanis',
#  'Balochis',
#  'Bamars',
#  'Bambara',
#  'Bashkirs',
#  'Basques',
#  'Belarusians',
#  'Bemba',
#  'Bengalis',
#  'Berbers',
#  'Beti-Pahuin',
#  'Bosniaks',
#  'Brahui',
#  'British',
#  'Bulgarians',
#  'Catalans',
#  'Chuvash',
#  'Circassians',
#  'Chewa',
#  'Cornish',
#  'Croats',
#  'Czechs',
#  'Danes',
#  'Dinka',
#  'Dutch',
#  'English',
#  'Estonians',
#  'Faroese',
#  'Finns',
#  'French',
#  'Frisians',
#  'Fula',
#  'Ga-Adangbe',
#  'Gagauz',
#  'Galician',
#  'Ganda',
#  'Germans',
#  'Greeks',
#  'Georgians',
#  'Gujarati',
#  'Han Chinese',
#  'Hausa',
#  'Hindustani',
#  'Hui',
#  'Hungarians',
#  'Ibibio',
#  'Icelanders',
#  'Igbo',
#  'Ijaw',
#  'Irish',
#  'Italians',
#  'Japanese',
#  'Javanese',
#  'Jews',
#  'Kannadigas',
#  'Kannada',
#  'Kashmiris',
#  'Kazakhs',
#  'Kikuyu',
#  'Kongo',
# ...

# %%
import pickle

# %%
frequency_filtered_list = []
# write code to check if words are in google n-grams all
with open('list-of-ethnic-slurs.csv') as infile:
    word_list =  infile.read().split('\n')

# %%
for line in word_list:
    words = line.split('\t')[0]
    for word in words.split(','):
        for year in range(1900, 2000, 10):
            print year, word
# Out:
# 1900 Abbie
# 1910 Abbie
# 1920 Abbie
# 1930 Abbie
# 1940 Abbie
# 1950 Abbie
# 1960 Abbie
# 1970 Abbie
# 1980 Abbie
# 1990 Abbie
# 1900   Abe
# 1910   Abe
# 1920   Abe
# 1930   Abe
# 1940   Abe
# 1950   Abe
# 1960   Abe
# 1970   Abe
# 1980   Abe
# 1990   Abe
# 1900   Abie
# 1910   Abie
# 1920   Abie
# 1930   Abie
# 1940   Abie
# 1950   Abie
# 1960   Abie
# 1970   Abie
# 1980   Abie
# 1990   Abie
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 1900 ABC
# 1910 ABC
# 1920 ABC
# 1930 ABC
# 1940 ABC
# 1950 ABC
# 1960 ABC
# 1970 ABC
# 1980 ABC
# 1990 ABC
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 1900 ABCD
# 1910 ABCD
# 1920 ABCD
# 1930 ABCD
# 1940 ABCD
# 1950 ABCD
# 1960 ABCD
# 1970 ABCD
# 1980 ABCD
# 1990 ABCD
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 1900 Abib
# 1910 Abib
# 1920 Abib
# 1930 Abib
# 1940 Abib
# 1950 Abib
# 1960 Abib
# 1970 Abib
# 1980 Abib
# 1990 Abib
# 1900  Abeed
# 1910  Abeed
# ...
